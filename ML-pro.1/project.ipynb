# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error
import numpy as np

data = pd.read_csv("student.csv")

X = data[['Hours']] # Double brackets - 2D input.
y = data[['Score']] 

model = LinearRegression()
model.fit(X,y)

predicted_score = model.predict(X)

mae = mean_absolute_error(y,predicted_score)
mse = mean_squared_error(y,predicted_score)
rmse = np.sqrt(mse)

print("Mean Absolue Error ",mae)
print("Mean Squared Error ",mse)
print("Root Mean Squared Error ",rmse)

new_hours = float(input("Enter a hours ="))
new_pred = model.predict([[new_hours]])

print(f"\nPrediction for {new_hours} is score = {new_pred}")
# Out:
# Mean Absolue Error  5.358490566037735
# Mean Squared Error  30.15849056603772
# Root Mean Squared Error  5.4916746595221495
#
# Prediction for 15.0 is score = [[142.01886792]]
# c:\Users\Asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
